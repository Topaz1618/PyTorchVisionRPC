# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory


data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join('dataset', x),
                                          data_transforms[x])
                  for x in ['train', 'val']}

class_names = image_datasets['train'].classes
print(class_names)
# Out:
# ['ants', 'bees']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def resnet_detect(images_path, model_name=None):
    
    if not model_name:
        print(f"Model name is not provided, use default model")
        model_path = "models/resnet_epoch_3.pt"
    else:
        model_path = os.path.join("models", model_name)
        if not os.path.exists(model_path):
            print(f"{model_name} does not exist, use default model")
            model_path = "models/resnet_epoch_3.pt"
        
    # 加载模型
    model = models.resnet50(pretrained=False)
    model.fc = nn.Linear(model.fc.in_features, len(class_names))
    model.load_state_dict(torch.load(model_path))
    model = model.to(device)
    model.eval()
    
    # Todo: 加 log
    print('Model loaded')
    
    # 加载图像
    res = []
   
    all_images = os.listdir(images_path)
    img_count = len(all_images)
    for idx, img_name in enumerate(all_images):
        # Todo: 加日志 idx/img_count 

        image_path = os.path.join(images_path, img_name)
        image = Image.open(image_path)
        image = data_transforms['val'](image).unsqueeze(0).to(device)
    
        # 预测
        outputs = model(image)
        _, preds = torch.max(outputs, 1)

        if preds:
            label = class_names[preds.item()]
        else:
            label = "unknown"

        res.append({"img_name": img_name, "class": {label}})
        
        # Todo: 加日志 log  f"{img}" 处理已完成，预测类别为 {label}
        print(f'The file {img_name} predicted class is: {label}')     

        
    print("res", res)
    
    # Todo: 结果保存到 MongoDB 
    
if __name__ == "__main__":
    images_path = 'dataset/val/bees'
    res = resnet_detect(image_path)
# Out:
# Model name is not provided, use default model
# Model loaded
# The file 1297972485_33266a18d9.jpg predicted class is: bees
# The file 2321144482_f3785ba7b2.jpg predicted class is: bees
# The file 144098310_a4176fd54d.jpg predicted class is: bees
# The file 1328423762_f7a88a8451.jpg predicted class is: bees
# The file 26589803_5ba7000313.jpg predicted class is: bees
# The file 1032546534_06907fe3b3.jpg predicted class is: bees
# The file 1519368889_4270261ee3.jpg predicted class is: unknown
# The file 348291597_ee836fbb1a.jpg predicted class is: bees
# The file 151603988_2c6f7d14c7.jpg predicted class is: bees
# The file 2501530886_e20952b97d.jpg predicted class is: bees
# The file 215512424_687e1e0821.jpg predicted class is: bees
# The file 2525379273_dcb26a516d.jpg predicted class is: unknown
# The file 1355974687_1341c1face.jpg predicted class is: bees
# The file 2815838190_0a9889d995.jpg predicted class is: bees
# The file 65038344_52a45d090d.jpg predicted class is: bees
# The file 353266603_d3eac7e9a0.jpg predicted class is: bees
# The file 57459255_752774f1b2.jpg predicted class is: unknown
# The file 177677657_a38c97e572.jpg predicted class is: bees
# The file 152789693_220b003452.jpg predicted class is: bees
# The file 2509402554_31821cb0b6.jpg predicted class is: unknown
# The file 603709866_a97c7cfc72.jpg predicted class is: unknown
# The file 2470492902_3572c90f75.jpg predicted class is: bees
# The file 372228424_16da1f8884.jpg predicted class is: bees
# The file 44105569_16720a960c.jpg predicted class is: bees
# The file 2668391343_45e272cd07.jpg predicted class is: bees
# The file 2407809945_fb525ef54d.jpg predicted class is: bees
# The file 149973093_da3c446268.jpg predicted class is: bees
# The file 1181173278_23c36fac71.jpg predicted class is: bees
# The file 759745145_e8bc776ec8.jpg predicted class is: bees
# The file 2685605303_9eed79d59d.jpg predicted class is: bees
# The file 2809496124_5f25b5946a.jpg predicted class is: bees
# The file 2103637821_8d26ee6b90.jpg predicted class is: bees
# The file 2741763055_9a7bb00802.jpg predicted class is: unknown
# The file 2745389517_250a397f31.jpg predicted class is: bees
# The file 203868383_0fcbb48278.jpg predicted class is: bees
# The file 1799729694_0c40101071.jpg predicted class is: bees
# The file 238161922_55fa9a76ae.jpg predicted class is: bees
# The file 590318879_68cf112861.jpg predicted class is: bees
# The file 187130242_4593a4c610.jpg predicted class is: bees
# The file 6a00d8341c630a53ef00e553d0beb18834-800wi.jpg predicted class is: bees
# The file 2104135106_a65eede1de.jpg predicted class is: unknown
# The file 2670536155_c170f49cd0.jpg predicted class is: unknown
# The file 2883093452_7e3a1eb53f.jpg predicted class is: bees
# The file 224841383_d050f5f510.jpg predicted class is: bees
# The file 416144384_961c326481.jpg predicted class is: unknown
# The file 151594775_ee7dc17b60.jpg predicted class is: bees
# The file 1486120850_490388f84b.jpg predicted class is: bees
# The file 2173503984_9c6aaaa7e2.jpg predicted class is: bees
# The file abeja.jpg predicted class is: bees
# The file 2415414155_1916f03b42.jpg predicted class is: bees
# The file 59798110_2b6a3c8031.jpg predicted class is: unknown
# The file 586474709_ae436da045.jpg predicted class is: bees
# The file 2060668999_e11edb10d0.jpg predicted class is: bees
# The file 2478216347_535c8fe6d7.jpg predicted class is: bees
# The file 2717418782_bd83307d9f.jpg predicted class is: bees
# The file 272986700_d4d4bf8c4b.jpg predicted class is: bees
# The file 2506114833_90a41c5267.jpg predicted class is: bees
# The file 576452297_897023f002.jpg predicted class is: bees
# The file 2457841282_7867f16639.jpg predicted class is: bees
# The file 72100438_73de9f17af.jpg predicted class is: bees
# The file 296565463_d07a7bed96.jpg predicted class is: bees
# The file 2086294791_6f3789d8a6.jpg predicted class is: bees
# The file 54736755_c057723f64.jpg predicted class is: bees
# The file 2841437312_789699c740.jpg predicted class is: bees
# The file 2444778727_4b781ac424.jpg predicted class is: unknown
# The file 290082189_f66cb80bfc.jpg predicted class is: bees
# The file 2709775832_85b4b50a57.jpg predicted class is: unknown
# The file 603711658_4c8cd2201e.jpg predicted class is: unknown
# The file 10870992_eebeeb3a12.jpg predicted class is: bees
# The file 2702408468_d9ed795f4f.jpg predicted class is: bees
# The file 540976476_844950623f.jpg predicted class is: bees
# The file 400262091_701c00031c.jpg predicted class is: bees
# The file 485743562_d8cc6b8f73.jpg predicted class is: bees
# The file 220376539_20567395d8.jpg predicted class is: bees
# The file 936182217_c4caa5222d.jpg predicted class is: bees
# The file 350436573_41f4ecb6c8.jpg predicted class is: unknown
# The file 456097971_860949c4fc.jpg predicted class is: bees
# The file 181171681_c5a1a82ded.jpg predicted class is: bees
# The file 464594019_1b24a28bb1.jpg predicted class is: bees
# The file 2438480600_40a1249879.jpg predicted class is: bees
# The file 2782079948_8d4e94a826.jpg predicted class is: bees
# The file 3077452620_548c79fda0.jpg predicted class is: bees
# The file 2751836205_6f7b5eff30.jpg predicted class is: bees
# res [{'img_name': '1297972485_33266a18d9.jpg', 'class': {'bees'}}, {'img_name': '2321144482_f3785ba7b2.jpg', 'class': {'bees'}}, {'img_name': '144098310_a4176fd54d.jpg', 'class': {'bees'}}, {'img_name': '1328423762_f7a88a8451.jpg', 'class': {'bees'}}, {'img_name': '26589803_5ba7000313.jpg', 'class': {'bees'}}, {'img_name': '1032546534_06907fe3b3.jpg', 'class': {'bees'}}, {'img_name': '1519368889_4270261ee3.jpg', 'class': {'unknown'}}, {'img_name': '348291597_ee836fbb1a.jpg', 'class': {'bees'}}, {'img_name': '151603988_2c6f7d14c7.jpg', 'class': {'bees'}}, {'img_name': '2501530886_e20952b97d.jpg', 'class': {'bees'}}, {'img_name': '215512424_687e1e0821.jpg', 'class': {'bees'}}, {'img_name': '2525379273_dcb26a516d.jpg', 'class': {'unknown'}}, {'img_name': '1355974687_1341c1face.jpg', 'class': {'bees'}}, {'img_name': '2815838190_0a9889d995.jpg', 'class': {'bees'}}, {'img_name': '65038344_52a45d090d.jpg', 'class': {'bees'}}, {'img_name': '353266603_d3eac7e9a0.jpg', 'class': {'bees'}}, {'img_name': '57459255_752774f1b2.jpg', 'class': {'unknown'}}, {'img_name': '177677657_a38c97e572.jpg', 'class': {'bees'}}, {'img_name': '152789693_220b003452.jpg', 'class': {'bees'}}, {'img_name': '2509402554_31821cb0b6.jpg', 'class': {'unknown'}}, {'img_name': '603709866_a97c7cfc72.jpg', 'class': {'unknown'}}, {'img_name': '2470492902_3572c90f75.jpg', 'class': {'bees'}}, {'img_name': '372228424_16da1f8884.jpg', 'class': {'bees'}}, {'img_name': '44105569_16720a960c.jpg', 'class': {'bees'}}, {'img_name': '2668391343_45e272cd07.jpg', 'class': {'bees'}}, {'img_name': '2407809945_fb525ef54d.jpg', 'class': {'bees'}}, {'img_name': '149973093_da3c446268.jpg', 'class': {'bees'}}, {'img_name': '1181173278_23c36fac71.jpg', 'class': {'bees'}}, {'img_name': '759745145_e8bc776ec8.jpg', 'class': {'bees'}}, {'img_name': '2685605303_9eed79d59d.jpg', 'class': {'bees'}}, {'img_name': '2809496124_5f25b5946a.jpg', 'class': {'bees'}}, {'img_name': '2103637821_8d26ee6b90.jpg', 'class': {'bees'}}, {'img_name': '2741763055_9a7bb00802.jpg', 'class': {'unknown'}}, {'img_name': '2745389517_250a397f31.jpg', 'class': {'bees'}}, {'img_name': '203868383_0fcbb48278.jpg', 'class': {'bees'}}, {'img_name': '1799729694_0c40101071.jpg', 'class': {'bees'}}, {'img_name': '238161922_55fa9a76ae.jpg', 'class': {'bees'}}, {'img_name': '590318879_68cf112861.jpg', 'class': {'bees'}}, {'img_name': '187130242_4593a4c610.jpg', 'class': {'bees'}}, {'img_name': '6a00d8341c630a53ef00e553d0beb18834-800wi.jpg', 'class': {'bees'}}, {'img_name': '2104135106_a65eede1de.jpg', 'class': {'unknown'}}, {'img_name': '2670536155_c170f49cd0.jpg', 'class': {'unknown'}}, {'img_name': '2883093452_7e3a1eb53f.jpg', 'class': {'bees'}}, {'img_name': '224841383_d050f5f510.jpg', 'class': {'bees'}}, {'img_name': '416144384_961c326481.jpg', 'class': {'unknown'}}, {'img_name': '151594775_ee7dc17b60.jpg', 'class': {'bees'}}, {'img_name': '1486120850_490388f84b.jpg', 'class': {'bees'}}, {'img_name': '2173503984_9c6aaaa7e2.jpg', 'class': {'bees'}}, {'img_name': 'abeja.jpg', 'class': {'bees'}}, {'img_name': '2415414155_1916f03b42.jpg', 'class': {'bees'}}, {'img_name': '59798110_2b6a3c8031.jpg', 'class': {'unknown'}}, {'img_name': '586474709_ae436da045.jpg', 'class': {'bees'}}, {'img_name': '2060668999_e11edb10d0.jpg', 'class': {'bees'}}, {'img_name': '2478216347_535c8fe6d7.jpg', 'class': {'bees'}}, {'img_name': '2717418782_bd83307d9f.jpg', 'class': {'bees'}}, {'img_name': '272986700_d4d4bf8c4b.jpg', 'class': {'bees'}}, {'img_name': '2506114833_90a41c5267.jpg', 'class': {'bees'}}, {'img_name': '576452297_897023f002.jpg', 'class': {'bees'}}, {'img_name': '2457841282_7867f16639.jpg', 'class': {'bees'}}, {'img_name': '72100438_73de9f17af.jpg', 'class': {'bees'}}, {'img_name': '296565463_d07a7bed96.jpg', 'class': {'bees'}}, {'img_name': '2086294791_6f3789d8a6.jpg', 'class': {'bees'}}, {'img_name': '54736755_c057723f64.jpg', 'class': {'bees'}}, {'img_name': '2841437312_789699c740.jpg', 'class': {'bees'}}, {'img_name': '2444778727_4b781 ...

# %%
# Out:
# ['1297972485_33266a18d9.jpg',
#  '2321144482_f3785ba7b2.jpg',
#  '144098310_a4176fd54d.jpg',
#  '1328423762_f7a88a8451.jpg',
#  '26589803_5ba7000313.jpg',
#  '1032546534_06907fe3b3.jpg',
#  '1519368889_4270261ee3.jpg',
#  '348291597_ee836fbb1a.jpg',
#  '151603988_2c6f7d14c7.jpg',
#  '2501530886_e20952b97d.jpg',
#  '215512424_687e1e0821.jpg',
#  '2525379273_dcb26a516d.jpg',
#  '1355974687_1341c1face.jpg',
#  '2815838190_0a9889d995.jpg',
#  '65038344_52a45d090d.jpg',
#  '353266603_d3eac7e9a0.jpg',
#  '57459255_752774f1b2.jpg',
#  '177677657_a38c97e572.jpg',
#  '152789693_220b003452.jpg',
#  '2509402554_31821cb0b6.jpg',
#  '603709866_a97c7cfc72.jpg',
#  '2470492902_3572c90f75.jpg',
#  '372228424_16da1f8884.jpg',
#  '44105569_16720a960c.jpg',
#  '2668391343_45e272cd07.jpg',
#  '2407809945_fb525ef54d.jpg',
#  '149973093_da3c446268.jpg',
#  '1181173278_23c36fac71.jpg',
#  '759745145_e8bc776ec8.jpg',
#  '2685605303_9eed79d59d.jpg',
#  '2809496124_5f25b5946a.jpg',
#  '2103637821_8d26ee6b90.jpg',
#  '2741763055_9a7bb00802.jpg',
#  '2745389517_250a397f31.jpg',
#  '203868383_0fcbb48278.jpg',
#  '1799729694_0c40101071.jpg',
#  '238161922_55fa9a76ae.jpg',
#  '590318879_68cf112861.jpg',
#  '187130242_4593a4c610.jpg',
#  '6a00d8341c630a53ef00e553d0beb18834-800wi.jpg',
#  '2104135106_a65eede1de.jpg',
#  '2670536155_c170f49cd0.jpg',
#  '2883093452_7e3a1eb53f.jpg',
#  '224841383_d050f5f510.jpg',
#  '416144384_961c326481.jpg',
#  '151594775_ee7dc17b60.jpg',
#  '1486120850_490388f84b.jpg',
#  '2173503984_9c6aaaa7e2.jpg',
#  'abeja.jpg',
#  '2415414155_1916f03b42.jpg',
#  '59798110_2b6a3c8031.jpg',
#  '586474709_ae436da045.jpg',
#  '2060668999_e11edb10d0.jpg',
#  '2478216347_535c8fe6d7.jpg',
#  '2717418782_bd83307d9f.jpg',
#  '272986700_d4d4bf8c4b.jpg',
#  '2506114833_90a41c5267.jpg',
#  '576452297_897023f002.jpg',
#  '2457841282_7867f16639.jpg',
#  '72100438_73de9f17af.jpg',
#  '296565463_d07a7bed96.jpg',
#  '2086294791_6f3789d8a6.jpg',
#  '54736755_c057723f64.jpg',
#  '2841437312_789699c740.jpg',
#  '2444778727_4b781ac424.jpg',
#  '290082189_f66cb80bfc.jpg',
#  '2709775832_85b4b50a57.jpg',
#  '603711658_4c8cd2201e.jpg',
#  '10870992_eebeeb3a12.jpg',
#  '2702408468_d9ed795f4f.jpg',
#  '540976476_844950623f.jpg',
#  '400262091_701c00031c.jpg',
#  '485743562_d8cc6b8f73.jpg',
#  '220376539_20567395d8.jpg',
#  '936182217_c4caa5222d.jpg',
#  '350436573_41f4ecb6c8.jpg',
#  '456097971_860949c4fc.jpg',
#  '181171681_c5a1a82ded.jpg',
#  '464594019_1b24a28bb1.jpg',
#  '2438480600_40a1249879.jpg',
#  '2782079948_8d4e94a826.jpg',
#  '3077452620_548c79fda0.jpg',
#  '2751836205_6f7b5eff30.jpg']
